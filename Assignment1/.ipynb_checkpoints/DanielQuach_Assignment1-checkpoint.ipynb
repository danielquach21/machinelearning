# %% [markdown]
# # Assignment #1 - Linear Regression
#
# <font color="red"> <b> Due: Feb 14 (Friday) 11:00 pm </b> </font>

# %% [markdown]
# <font color="blue"> Daniel Quach </font>

# %% [markdown]
# # Introduction
#
# The objective of this assignment is to calculate which characteristic has the greatest positive effect on wine quality. The linear regression model will be used to calculate which feature of wine has the highest residual value when compared to overall wine quality. There may be more than one factor that affects this rating.

# %% [markdown]
# # Data
#
# https://archive.ics.uci.edu/ml/datasets/Wine+Quality
#
# The data set I have chosen for this assignment is one that describes different elements of two different types of wine, either red or white, and their corresponding qualities. On the surface, there seems to be no correlation between most of the characteristics except a certain few: pH, alcohol, density, and volatile acidity.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib inline

# %% [markdown]
# Importing the dataset into the notebook.

# %%
data = pd.read_csv("winequalityN.csv")
data2 = pd.read_csv("winequalityN.csv")
data
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# ### "data2" is a custom dataset using values from the original dataset but with an even number of wines of each quality value.

# %%
data = data.dropna()
data2 = data[data['quality']==5][:5]
data2 = data2.append(data[data['quality']==6][:5])
data2 = data2.append(data[data['quality']==7][:5])
data2 = data2.append(data[data['quality']==8][:5])
data2 = data2.append(data[data['quality']==9][:5])
data2
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 10    white            8.1              0.27         0.41            1.45
# 11    white            8.6              0.23         0.40            4.20
# 12    white            7.9              0.18         0.37            1.20
# 14    white            8.3              0.42         0.62           19.25
# 19    white            6.5              0.31         0.14            7.50
# 0     white            7.0              0.27         0.36           20.70
# 1     white            6.3              0.30         0.34            1.60
# 2     white            8.1              0.28         0.40            6.90
# 3     white            7.2              0.23         0.32            8.50
# 4     white            7.2              0.23         0.32            8.50
# 13    white            6.6              0.16         0.40            1.50
# 15    white            6.6              0.17         0.38            1.50
# ...

# %% [markdown]
# Below I have separated the data based on their individual quality ratings.

# %%
best = data.loc[data.loc[:, 'quality'] == 9, :]
best
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 774   white            9.1              0.27         0.45            10.6
# 820   white            6.6              0.36         0.29             1.6
# 827   white            7.4              0.24         0.36             2.0
# 876   white            6.9              0.36         0.34             4.2
# 1605  white            7.1              0.26         0.49             2.2
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 774       0.035                 28.0                 124.0  0.99700  3.20
# 820       0.021                 24.0                  85.0  0.98965  3.41
# 827       0.031                 27.0                 139.0  0.99055  3.28
# 876       0.018                 57.0                 119.0  0.98980  3.28
# 1605      0.032                 31.0                 113.0  0.99030  3.37
#
#       sulphates  alcohol  quality
# 774        0.46     10.4        9
# ...

# %%
better = data.loc[data.loc[:, 'quality'] == 8, :]
better
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 17    white            NaN              0.66         0.48             1.2
# 20    white            6.2              0.66         0.48             1.2
# 22    white            6.8              0.26         0.42             1.7
# 68    white            6.7              0.23         0.31             2.1
# 74    white            6.7              0.23         0.31             2.1
# ...     ...            ...               ...          ...             ...
# 6100    red            8.6              0.42         0.39             1.8
# 6167    red            5.5              0.49         0.03             1.8
# 6301    red            7.2              0.33         0.33             1.7
# 6347    red            7.2              0.38         0.31             2.0
# 6447    red            7.4              0.36         0.30             1.8
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
great = data.loc[data.loc[:, 'quality'] == 7, :]
great
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 13    white            6.6              0.16         0.40             1.5
# 15    white            6.6              0.17         0.38             1.5
# 21    white            6.4              0.31         0.38             2.9
# 29    white            7.2              0.32         0.36             2.0
# 45    white            7.4              0.18         0.31             1.4
# ...     ...            ...               ...          ...             ...
# 6432    red            6.6              0.56         0.14             2.4
# 6439    red            7.4              0.25         0.29             2.2
# 6442    red            8.4              0.37         0.43             2.3
# 6453    red            7.0              0.56         0.17             1.7
# 6482    red            6.7              0.32         0.44             2.4
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
good = data.loc[data.loc[:, 'quality'] == 6, :]
good
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0              0.27         0.36            20.7
# 1     white            6.3              0.30         0.34             1.6
# 2     white            8.1              0.28         0.40             6.9
# 3     white            7.2              0.23         0.32             8.5
# 4     white            7.2              0.23         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6490    red            6.3              0.51         0.13             2.3
# 6491    red            6.8              0.62         0.08             1.9
# 6493    red            5.9              0.55         0.10             2.2
# 6494    red            6.3              0.51         0.13             2.3
# 6496    red            6.0              0.31         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
average = data.loc[data.loc[:, 'quality'] <= 5, :]
average
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 10    white            8.1             0.270         0.41            1.45
# 11    white            8.6             0.230         0.40            4.20
# 12    white            7.9             0.180         0.37            1.20
# 14    white            8.3             0.420         0.62           19.25
# 19    white            6.5             0.310         0.14            7.50
# ...     ...            ...               ...          ...             ...
# 6480    red            6.1             0.715         0.10            2.60
# 6481    red            6.2             0.460         0.29            2.10
# 6487    red            6.6             0.725         0.20            7.80
# 6492    red            6.2             0.600         0.08            2.00
# 6495    red            5.9             0.645         0.12            2.00
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# # Method
#
# ## Least Squares
# The least squares method is an analysis tool using regression to determine what line best fits the data set with the highest accuracy. The question that this principal answers is "How do we know what line most accurately represents the data. I used the least squares method to visualize what factors affected the overall quality of each wine.
#
# ## Least Mean Squares
# The least mean squares regression model is similar to the least squares method but it also calculates the mean of the error. I was not able to use this model very well in my experiments simply because I was struggling with avoiding the log runtime errors.

# %% [markdown]
# ### Super Classs Definition

# %%
import numpy as np 
from abc import ABC, abstractmethod

# Super class for machine learning models 

class BaseModel(ABC):
    """ Super class for ITCS Machine Learning Class"""
    
    @abstractmethod
    def train(self, X, T):
        pass

    @abstractmethod
    def use(self, X):
        pass

    
class LinearModel(BaseModel):
    """
        Abstract class for a linear model 
        
        Attributes
        ==========
        w       ndarray
                weight vector/matrix
    """

    def __init__(self):
        """
            weight vector w is initialized as None
        """
        self.w = None

    # check if the matrix is 2-dimensional. if not, raise an exception    
    def _check_matrix(self, mat, name):
        if len(mat.shape) != 2:
            raise ValueError(''.join(["Wrong matrix ", name]))
        
    # add a basis
    def add_ones(self, X):
        """
            add a column basis to X input matrix
        """
        self._check_matrix(X, 'X')
        return np.hstack((np.ones((X.shape[0], 1)), X))

    ####################################################
    #### abstract funcitons ############################
    @abstractmethod
    def train(self, X, T):
        """
            train linear model
            
            parameters
            -----------
            X     2d array
                  input data
            T     2d array
                  target labels
        """        
        pass
    
    @abstractmethod
    def use(self, X):
        """
            apply the learned model to input X
            
            parameters
            ----------
            X     2d array
                  input data
            
        """        
        pass

# %% [markdown]
# ### Least Squares

# %%
# Linear Regression Class for least squares
class LinearRegress(LinearModel): 
    """ 
        LinearRegress class 
        
        attributes
        ===========
        w    nd.array  (column vector/matrix)
             weights
    """
    def __init__(self):
        LinearModel.__init__(self)
        
    # train least-squares model
    def train(self, X, T):
        N = len(X)
        y = np.ones((N,1))
        x1 = np.hstack((y,X))
        self.w = np.linalg.pinv(x1.T@x1) @ x1.T @ T

        
    # apply the learned model to data X
    def use(self, X):
        N = len(X)
        y = np.ones((N,1))
        x1 = np.hstack((y,X))
        Y = x1 @ self.w
        return Y

# %% [markdown]
# ### Least Mean Squares

# %%
import collections # for checking iterable instance

# LMS class 
class LMS(LinearModel):
    """
        Least Mean Squares. online learning algorithm
    
        attributes
        ==========
        w        nd.array
                 weight matrix
        alpha    float
                 learning rate
    """
    def __init__(self, alpha):
        LinearModel.__init__(self)
        self.alpha = alpha
    
    # batch training by using train_step function
    def train(self, X, T):
        N = len(X)
        for k in range(N):
            self.train_step(X[k], T[k])
            
            
    # train LMS model one step 
    # here the x is 1d vector
    def train_step(self, x, t):
        self.add_ones(X)
        if(self.w is None):
            self.w = self.alpha * (x - np.log(t+1)) * x
        self.w = self.w - self.alpha * ((self.w.T @ x) - np.log(t+1)) * x
        
    # apply the current model to data X
    def use(self, X):
        Y = X @ self.w
        return Y

# %% [markdown]
# ### Preliminary Test
#
# In this following tests, we examine if the implementation is correct with a simple test data, $f(x) = -2 x + 3.2$ where $x \in \{0, 1, 2, \dots, 9, 10 \}$.

# %%
# HERE follow are for my code tests.

import matplotlib.pyplot as plt
# %matplotlib inline

X = np.linspace(0,10, 11).reshape((-1, 1))
T = -2 * X + 3.2

# %%
# least square model
ls = LinearRegress()

ls.train(X, T)
plt.plot(ls.use(X))

# %%
# least mean square model
lms = LMS(0.1)
for x, t in zip(X, T):
    lms.train_step(x, t)
    plt.plot(lms.use(X))
# Out:
# C:\Users\Daniel\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: RuntimeWarning: invalid value encountered in log

# %%
lms.train(X, T)
plt.plot(lms.use(X))
# Out:
# C:\Users\Daniel\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: RuntimeWarning: invalid value encountered in log

# %% [markdown]
# # Experiments
#
# Below I have experimented with the data using the least squares regression to try and find what characteristic had the greatest effect on wine quality. The first plot below shows a pretty inaccurate model. I believe it is inaccurate mainly due to the fact that there are too many characteristics being used to try and predict the quality value. Further down I have separated the training data into the areas which I found to have the highest correlation values with quality.

# %%
ls = LinearRegress()
data = data.dropna()
X = data.iloc[:,1:-1]
T = data.loc[:, 'quality']
X = X.values
T = T.values

ls.train(X, T)
plt.plot(T[:100], 'ob')
plt.plot(ls.use(X[:100]), 'xr')

# %% [markdown]
# There is not much of a difference between the above plot and the one below it except for a few values. There are more hits and closer predictions in the plot below. The plots further below are each individual major value being used individually as testing data.

# %%
ls = LinearRegress()
data = data.dropna()
X = data.loc[:,['alcohol', 'volatile acidity', 'sulphates', 'density']]
T = data.loc[:, 'quality']
X = X.values
T = T.values

ls.train(X, T)
plt.plot(T[:100], 'ob')
plt.plot(ls.use(X[:100]), 'xr')

# %%
ls = LinearRegress()
data = data.dropna()
X = data.loc[:, ['alcohol']]
T = data.loc[:, 'quality']
X = X.values
T = T.values

ls.train(X, T)
plt.plot(T[:100], 'ob')
plt.plot(ls.use(X[:100]), 'xr')

# %%
ls = LinearRegress()
data = data.dropna()
X = data.loc[:,['volatile acidity']]
T = data.loc[:, 'quality']
X = X.values
T = T.values

ls.train(X, T)
plt.plot(T[:100], 'ob')
plt.plot(ls.use(X[:100]), 'xr')

# %% [markdown]
# Sulphates seem to be the same value between all qualities of wine.

# %%
ls = LinearRegress()
data = data.dropna()
X = data.loc[:,['sulphates']]
T = data.loc[:, 'quality']
X = X.values
T = T.values

ls.train(X, T)
plt.plot(T[:100], 'ob')
plt.plot(ls.use(X[:100]), 'xr')

# %%
ls = LinearRegress()
data = data.dropna()
X = data.loc[:,['density', 'alcohol', 'pH']]
T = data.loc[:, 'quality']
X = X.values
T = T.values

ls.train(X, T)
plt.plot(T[:100], 'ob')
plt.plot(ls.use(X[:100]), 'xr')

# %% [markdown]
# ## At this point, I wanted to see if there was better predictions when using a data set that was not skewed with so much of the average value (between 5 and 6).
# With the new balanced dataset, I was able to achieve more meaningful results as seen the following graphs below.

# %%
ls = LinearRegress()
data = data.dropna()
X = data2.loc[:,['density','alcohol', 'pH']]
T = data2.loc[:, 'quality']
X = X.values
T = T.values

ls.train(X, T)
plt.plot(T, 'ob')
plt.plot(ls.use(X), 'xr')

# %% [markdown]
# Volatile acidity had lesser value in accuracy with the more balanced dataset.

# %%
ls = LinearRegress()
data = data.dropna()
X = data2.loc[:,['volatile acidity']]
T = data2.loc[:, 'quality']
X = X.values
T = T.values

ls.train(X, T)
plt.plot(T, 'ob')
plt.plot(ls.use(X), 'xr')

# %%
ls = LinearRegress()
data = data.dropna()
X = data2.loc[:,['pH']]
T = data2.loc[:, 'quality']
X = X.values
T = T.values

ls.train(X, T)
plt.plot(T, 'ob')
plt.plot(ls.use(X), 'xr')

# %%
ls = LinearRegress()
data = data.dropna()
X = data2.loc[:,['alcohol']]
T = data2.loc[:, 'quality']
X = X.values
T = T.values

ls.train(X, T)
plt.plot(T, 'ob')
plt.plot(ls.use(X), 'xr')

# %% [markdown]
# # Conclusions
#
# One challenge I faced throughout this assignment were that choosing to try and uncover what characteristics of wine affected overall quality. There are so many factors that go into wine and there does not seem to be one specific thing that determines this rating. With the balanced data set, there was an improvement but not enough to really help guide someone in making better wine. If I were to change one thing about my choices with this assignment, it would be to use the data and linear models to try and uncover if there was a determining factor that played into whether or not a wine was red or white; however, this would then be more of a classification experiment than a regression one.

# %% [markdown]
# # References
#
# https://archive.ics.uci.edu/ml/datasets/Wine+Quality<br>
# https://www.investopedia.com/terms/l/least-squares-method.asp<br>
# https://www.sciencedirect.com/topics/engineering/least-mean-square

# %% [markdown]
# ## Grading
#
# DO NOT forget to submit your data! Your notebook is supposed to run well after running your codes.
#
# ** Note: this is a WRITING assignment. Proper writing is REQUIRED. Comments are not considered as writing. **
#
#
# Points | | Description
# --|--|:--
# 5 | Introduction
# 20 | Data |
#  | 5| description
#  | 5| plots for understanding or analysis
#  | 5| preliminary observation
#  | 5| Preprocessing of the data
# 40 | Method |
#  | 5| review
#  | 5| explanation of codes
#  | 30| Correct implementation (preliminary test)
# 30 | Experiments |
#  | 5| description, codes
#  | 10| visualization of results
#  | 15| analysis / comparison of algorithms
# 5 | Conclusions, References

# %% [markdown]
# # Preliminary Test
#
# After finishing the implmentation of LinearRegress and LMS classes, run the following cell to test if your implementation is correct. Make sure and check your codes to pass all three tests as in sample outputs.

# %%
##################### WHAT I WILL RELEASE ############

# Self-Test code for accuracy of your model - DO NOT MODIFY THIS
# Primilnary test data
X = np.array([[2,5],
              [6,2],
              [1,9],
              [4,5],
              [6,3],
              [7,4],
              [8,3]])
T = X[:,0, None] * 3 - 2 * X[:, 1, None] + 3
N = X.shape[0]

def rmse(T, Y):
    return np.sqrt(np.sum((T-Y)**2))


model_names = ['LS', 'LMS_All', 'LMS_1STEP']
models = [LinearRegress(), LMS(0.02), LMS(0.02)]
#train
for i, model in enumerate(models):
    print("training ", model_names[i], "...") 
    if i == len(models) -1: 
        # train only one step for LMS2
        model.train_step(X[0], T[0])
    else:
        model.train(X, T)

def check(a, b, eps=np.finfo(float).eps):
    if abs(a-b) > eps:
        print("failed.", a, b)
    else:
        print("passed.")

errors = [1.19e-13, 2.8753214702, 38.0584918251]
for i, model in enumerate(models):
    print("---- Testing ", model_names[i], "...", end=" ") 
    
    # rmse test
    err = rmse(T, model.use(X))
    if check(err, errors[i], eps=1e-10):
        print ("check your weights: ", model.w)
        print ("oracle: ", )
# Out:
# training  LS ...
# training  LMS_All ...
# training  LMS_1STEP ...
# ---- Testing  LS ... passed.
# ---- Testing  LMS_All ... passed.
# ---- Testing  LMS_1STEP ... passed.
# C:\Users\Daniel\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: RuntimeWarning: divide by zero encountered in log
# C:\Users\Daniel\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: RuntimeWarning: divide by zero encountered in log
# C:\Users\Daniel\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: RuntimeWarning: invalid value encountered in subtract
# C:\Users\Daniel\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: RuntimeWarning: invalid value encountered in log
